# %% [markdown]
# # Clean Images
#
# Give image the correct name, and assign it a class

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir('/Users/bcasares/git_folders/cs231n/cs231n_project/')

# %%
from preprocess_data import renameImages
from download_images import loadData

# %%
data = loadData()
data.head()
# Out:
#    ZIPcode TaxRateArea_CITY         AIN  RollYear  TaxRateArea    AssessorID  \
# 0  90222.0          COMPTON  6145008013      2018         2800  6145-008-013
# 1  90222.0          COMPTON  6145008012      2018         2800  6145-008-012
# 2  90222.0          COMPTON  6145008004      2018         2800  6145-008-004
# 3  90222.0          COMPTON  6145007013      2018         2800  6145-007-013
# 4  93532.0   unincorporated  3225006017      2018         4500  3225-006-017
#
#                            PropertyLocation PropertyType PropertyUseCode  \
# 0        1415 W 132ND ST  COMPTON CA  90222          SFR            0100
# 1        1417 W 132ND ST  COMPTON CA  90222          SFR            0100
# 2        1412 W 131ST ST  COMPTON CA  90222          SFR            0100
# 3        1416 W 130TH ST  COMPTON CA  90222          SFR            0100
# 4  14440 CHIPTREE RD  LAKE HUGHES CA  93532          SFR            0100
#
#   GeneralUseType  ... HouseFraction StreetDirection   StreetName  UnitNo  \
# 0    Residential  ...           NaN               W     132ND ST     NaN
# 1    Residential  ...           NaN               W     132ND ST     NaN
# 2    Residential  ...           NaN               W     131ST ST     NaN
# 3    Residential  ...           NaN               W     130TH ST     NaN
# 4    Residential  ...           NaN             NaN  CHIPTREE RD     NaN
#
#              City  ZIPcode5           rowID  CENTER_LAT  CENTER_LON  \
# 0      COMPTON CA   90222.0  20186145008013   33.912488 -118.246963
# 1      COMPTON CA   90222.0  20186145008012   33.912487 -118.247128
# 2      COMPTON CA   90222.0  20186145008004   33.912817 -118.246963
# 3      COMPTON CA   90222.0  20186145007013   33.913709 -118.247127
# 4  LAKE HUGHES CA   93532.0  20183225006017   34.657489 -118.380921
#
#                             Location 1
# 0  (33.912487579999997, -118.24696283)
# 1   (33.91248744, -118.24712762999999)
# 2   (33.91281747, -118.24696307000001)
# 3          (33.9137092, -118.24712748)
# 4  (34.657489150000004, -118.38092118)
#
# [5 rows x 51 columns]

# %%
renameImages(source_directory="data/DOWNLOAD_HOUSES")
